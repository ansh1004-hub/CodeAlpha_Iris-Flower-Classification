# %% [markdown]
# # IRIS-FLOWER-CLASSIFICATION USING MACHINE LEARNING.

# %% [markdown]
# ## INTRODUCTION
# The aim is to classify Iris Flower among three species (setosa,versicolor,verginica) by using measurements of length and width of petals and sepals of flower.
#
# The iris.data set contains 3 classes of 50 instances each,where each class refers to a type of iris plant.
#
# The central goal here is to design a model that makes useful classifications for new flowers or,one which exhibits good generalization.
#
# The data source is the file iris.data.csv .It contains the data for this example in comma-separated values(CSV) format. The number of column is 5,and the number of rows is 150.

# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
# IMPORTING ALL THE ESSENTIAL LIBRARIES FOR OUR PROJECT 
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## LOADING THE DATASET

# %%
# DATASET 
df = pd.read_csv('iris.data.csv')
df.head(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## ANALYSIS ON THE DATASET

# %%
# Analysis 
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ## VISUALIZATION OF THE DATASET

# %% [markdown]
# ### PAIR PLOT
# A pair plot, also known as a scatterplot matrix, is a powerful data visualization tool that creates a grid of plots to show the relationships between all pairs of variables in a dataset.

# %%
sns.pairplot(df,hue='species')
plt.show()

# %% [markdown]
# ### HISTOGRAM
# A histogram is a fundamental and widely used type of data visualization that represents the distribution of a continuous numerical variable.

# %%
df.hist()
plt.show()

# %% [markdown]
# ### PIE CHART
# A circular chart divided into slices used to represent the proportions or percentages of a categorical dataset.

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
l = ['Versicolor', 'Setosa', 'Virginica']
s = [50,50,50]
ax.pie(s, labels = l, autopct='%1.2f%%')
plt.show()
# Out:
# Ignoring fixed x limits to fulfill fixed data aspect with adjustable data limits.

# %% [markdown]
# ### CHECKING FOR OUTLIARS
# A data point that is significantly different from the other observations in a dataset.

# %%
plt.figure(1)
plt.boxplot([df['sepal_length']])
plt.figure(2)
plt.boxplot([df['sepal_width']])
plt.show()
plt.figure(1)
plt.boxplot([df['petal_length']])
plt.figure(2)
plt.boxplot([df['petal_width']])
plt.show()

# %% [markdown]
# ### Kernel Density Estimate plot
#  A smooth, continuous curve that represents the probability density function of a numerical variable.

# %%
df.plot(kind ='density',subplots = True, layout =(3,3),sharex = False)
plt.show()

# %% [markdown]
# ### VIOLIN PLOTS
# A combination of a box plot and a KDE plot used to visualize the distribution of a numerical variable across different categories.

# %%
plt.figure(figsize=(15, 10))
plt.subplot(2, 2, 1)
sns.violinplot(x='species', y='petal_length', data=df)
plt.subplot(2, 2, 2)
sns.violinplot(x='species', y='petal_width', data=df)
plt.subplot(2, 2, 3)
sns.violinplot(x='species', y='sepal_length', data=df)
plt.subplot(2, 2, 4)
sns.violinplot(x='species', y='sepal_width', data=df)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##
# SEPARATING THE INPUT AND THE OUPUT COLUMN

# %%
#Separate features and the target 
data = df.values

X= data[:,0:4]   # Sepal_length,Sepal_width,Petal_length,Petal_width
Y= data[:,4]     # Species

# %% [markdown]
# ## SPLITTING THE DATA INTO TRAINING AND TESTING

# %%
# Split the data to train and test dataset.
from sklearn.model_selection import train_test_split
X_train , X_test ,Y_train , Y_test = train_test_split(X,Y,test_size = 0.2)


# X_train contains the Input used for training 
# Y_train contains the Output used for training 

# X_test  contains the Input used for test
# Y_test contains the Input used for test

# %% [markdown]
# ## MACHINE LEARNING AND PREDICTIONS

# %% [markdown]
# ### MODEL_1 : SUPPORT VECTOR MACHINE ALGORITHMS

# %%
# Support vector machine algorithm
from sklearn.svm import SVC 
model_svc = SVC()
model_svc.fit(X_train,Y_train)
# Out:
# SVC()

# %%
# prediction using model1
prediction1 = model_svc.predict(X_test)

# calculating the accuracy of model1
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,prediction1))
# Out:
# 0.9666666666666667

# %% [markdown]
# ### MODEL_2 : LOGISTIC REGRESSION

# %%
# logistic regression 
from sklearn.linear_model import LogisticRegression 
model_LR = LogisticRegression()
model_LR.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
# prediction using model2
prediction2 = model_LR.predict(X_test)

# calculating the accuracy of model2
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,prediction2))
# Out:
# 0.9666666666666667

# %% [markdown]
# ### MODEL_3 : DECISION TREE CLASSIFIER

# %%
# Decision Tree Classifier 
from sklearn.tree import DecisionTreeClassifier
model_DTC = DecisionTreeClassifier()
model_DTC.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier()

# %%
# prediction using model3
prediction3 = model_DTC.predict(X_test)

# calculating the accuracy of model3
from sklearn.metrics import accuracy_score
print(accuracy_score(Y_test,prediction3))
# Out:
# 0.8333333333333334

# %% [markdown]
# ## DEATAILED CLASSIFICATION REPORT TO EVALUATE THE PERFORMANCE OF MACHINE LEARNING CLASSIFICATION MODEL

# %%
# Classification Report 
from sklearn.metrics import classification_report
print(classification_report(Y_test,prediction2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      0.93      0.97        15
#  Iris-virginica       0.88      1.00      0.93         7
#
#        accuracy                           0.97        30
#       macro avg       0.96      0.98      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %% [markdown]
# ## TESTING THE MACHINE BY GIVING THE NEW DATA

# %%
#Testing 
X_new = np.array([ [3,2,1,0.2] , [4.9,2.2,3.8,1.1] , [5.3,2.5,4.6,1.9] ])   #Input

# Prediction of the species from the input data.
prediction = model_svc.predict(X_new)
print("Prediction of Species: {}".format(prediction))
# Out:
# Prediction of Species: ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
